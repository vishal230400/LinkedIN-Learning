# %% [markdown]
# ## The law of large numbers

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.dpi'] = 300
m = []
for n in np.linspace(1,8,30):
    t = np.random.normal(1,1,size=int(10**n))
    m.append(t.mean())
    N_points = 100000
n_bins = 20

plt.plot(m, 'r-', label='single sample mean', color='blue')
plt.ylabel('single sample mean')
plt.xlabel('10^n')
# Out:
# /var/folders/tq/jtgfkbln5bv4lmlbq2tvnq1h0000gn/T/ipykernel_35848/367814795.py:12: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(m, 'r-', label='single sample mean', color='blue')
# Text(0.5, 0, '10^n')
