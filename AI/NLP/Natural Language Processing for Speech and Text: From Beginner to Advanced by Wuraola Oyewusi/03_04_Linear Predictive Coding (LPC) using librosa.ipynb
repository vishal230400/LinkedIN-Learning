# %%
import numpy as np
import librosa
import matplotlib.pyplot as plt

# %%
y, sr = librosa.load('./NLP_sample_audio.wav')

# %%
order = 16
lpc_coefficients = librosa.lpc(y, order=order)

# %%
lpc_coefficients
# Out:
# array([ 1.        , -0.33967835, -0.17758839, -0.8687948 ,  0.3231702 ,
#        -0.09668063,  0.38110304, -0.33206987,  0.16222946, -0.10605079,
#         0.26651573, -0.1422597 ,  0.08383105, -0.14716162,  0.10846783,
#        -0.03832113,  0.05544063], dtype=float32)

# %%
lpc_coefficients.shape
# Out:
# (17,)

# %%
plt.figure(figsize=(10, 6))
plt.subplot(2,1,1)
plt.plot(lpc_coefficients.T, label='LPC Coefficients')
plt.xlabel('Frame Index')
plt.ylabel('LPC Coefficients')
plt.title(f'LPC Coefficients(order={order})')
plt.legend()
