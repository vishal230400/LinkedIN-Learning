# %% [markdown]
# [Transformers](https://huggingface.co/docs/transformers/en/index)

# %%
import torch
import torchaudio
from transformers import Wav2Vec2Processor, Wav2Vec2Model
# Out:
# /Users/vishalsankarram/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-base-960h")
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-base-960h")
# Out:
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-base-960h and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
audio_path = "./NLP_sample_audio.wav"

# %%
audio_input, sample_rate = torchaudio.load(audio_path)

# %%
audio_input
# Out:
# tensor([[ 0.0000,  0.0000,  0.0000,  ..., -0.0002, -0.0002, -0.0002],
#         [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]])

# %%
sample_rate
# Out:
# 48000

# %%
input_values = processor(audio_input, sampling_rate=sample_rate, return_tensors="pt")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 input_values = processor(audio_input, sampling_rate=sample_rate, return_tensors="pt")
#
# File ~/Library/Python/3.9/lib/python/site-packages/transformers/models/wav2vec2/processing_wav2vec2.py:95, in Wav2Vec2Processor.__call__(self, *args, **kwargs)
#      92     raise ValueError("You need to specify either an `audio` or `text` input to process.")
#      94 if audio is not None:
# ---> 95     inputs = self.feature_extractor(audio, *args, sampling_rate=sampling_rate, **kwargs)
#      96 if text is not None:
#      97     encodings = self.tokenizer(text, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/transformers/models/wav2vec2/feature_extraction_wav2vec2.py:174, in Wav2Vec2FeatureExtractor.__call__(self, raw_speech, padding, max_length, truncation, pad_to_multiple_of, return_attention_mask, return_tensors, sampling_rate, **kwargs)
#     172 if sampling_rate is not None:
#     173     if sampling_rate != self.sampling_rate:
# --> 174         raise ValueError(
#     175             f"The model corresponding to this feature extractor: {self} was trained using a sampling rate of"
#     176             f" {self.sampling_rate}. Please make sure that the provided `raw_speech` input was sampled with"
#     177             f" {self.sampling_rate} and not {sampling_rate}."
#     178         )
#     179 else:
#     180     logger.warning(
#     181         "It is strongly recommended to pass the ``sampling_rate`` argument to this function. "
#     182         "Failing to do so can result in silent errors that might be hard to debug."
#     183     )
#
# ValueError: The model corresponding to this feature extractor: Wav2Vec2FeatureExtractor {
#   "do_normalize": true,
#   "feature_extractor_type": "Wav2Vec2FeatureExtractor",
#   "feature_size": 1,
#   "padding_side": "right",
#   "padding_value": 0.0,
#   "return_attention_mask": false,
#   "sampling_rate": 16000
# }
#  was trained using a sampling rate of 16000. Please make sure that the provided `raw_speech` input was sampled with 16000 and not 48000.

# %%
resample_speech = torchaudio.transforms.Resample(orig_freq=sample_rate, new_freq=16000)(audio_input)

# %%
input_values = processor(resample_speech.squeeze().numpy(), return_tensors="pt")
# Out:
# It is strongly recommended to pass the ``sampling_rate`` argument to this function. Failing to do so can result in silent errors that might be hard to debug.

# %%
with torch.no_grad():
    output = model(**input_values)

# %%
output.last_hidden_state.shape
# Out:
# torch.Size([2, 600, 768])

# %%
output.last_hidden_state
# Out:
# tensor([[[-2.8313e-02,  4.2560e-02, -4.5139e-02,  ..., -2.9016e-01,
#            4.3965e-02, -4.4799e-03],
#          [-2.2972e-02,  4.0503e-02, -4.3333e-02,  ..., -2.8777e-01,
#            4.5689e-02, -6.3296e-03],
#          [-2.3948e-02,  4.0958e-02, -4.1602e-02,  ..., -2.8878e-01,
#            4.6640e-02, -6.2517e-03],
#          ...,
#          [-3.2487e-02,  6.1837e-02, -6.4588e-02,  ..., -2.9823e-01,
#            4.8786e-02,  1.7487e-03],
#          [-3.2536e-02,  7.4236e-02, -8.5617e-02,  ..., -3.1201e-01,
#            4.1741e-02,  8.8672e-03],
#          [-2.8567e-02,  4.6920e-02, -3.6513e-02,  ..., -2.7847e-01,
#            4.8712e-02,  8.8344e-03]],
#
#         [[-1.0796e-01,  1.3843e-02,  2.7779e-02,  ...,  8.3089e-05,
#            3.8994e-03,  2.1546e-02],
#          [-1.0028e-01,  1.7617e-02,  3.3556e-02,  ...,  1.6858e-04,
#           -1.8821e-02,  3.1268e-03],
#          [-1.1116e-01,  2.0320e-02,  2.7727e-02,  ...,  4.5864e-03,
#           -1.3077e-02,  2.1474e-03],
#          ...,
#          [-9.0107e-02,  2.1634e-02,  4.0657e-02,  ...,  1.5738e-02,
#           -2.9876e-02, -2.1558e-02],
#          [-9.3320e-02,  2.0758e-02,  3.7636e-02,  ...,  1.7387e-02,
#           -2.2952e-02, -1.3385e-02],
#          [-8.9516e-02,  1.8605e-02,  4.0900e-02,  ...,  1.8544e-02,
#           -2.5016e-02, -2.2385e-02]]])
