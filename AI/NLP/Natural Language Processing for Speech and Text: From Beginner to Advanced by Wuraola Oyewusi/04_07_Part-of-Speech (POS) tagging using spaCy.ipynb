# %% [markdown]
# [spaCy](https://spacy.io/usage/linguistic-features)

# %%
import spacy

# %%
#nlp = en_core_web_sm.load()
nlp = spacy.load("en_core_web_sm")

# %%
sentence = "Natural Language Processing for Speech and Text is Interesting"

# %%
doc = nlp(sentence)

# %%
for token in doc:
    print(token.text, token.pos_, token.tag_)
# Out:
# Natural PROPN NNP
# Language PROPN NNP
# Processing NOUN NN
# for ADP IN
# Speech PROPN NNP
# and CCONJ CC
# Text PROPN NNP
# is AUX VBZ
# Interesting ADJ JJ

# %%
for token in doc:
    print(token.text, token.lemma_, token.dep_, token.is_stop)
# Out:
# Natural Natural compound False
# Language Language compound False
# Processing processing nsubj False
# for for prep True
# Speech Speech pobj False
# and and cc True
# Text Text conj False
# is be ROOT True
# Interesting interesting acomp False

# %%
from spacy import displacy

# %%
displacy.render(doc, style="dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="c30dffe506c447cebaa68190ac01e6ee-0" class="displacy" width="1625" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Natural</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Language</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">Processing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">Speech</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">Text</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">Interesting</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADJ</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c30dffe506c447cebaa68190ac01e6ee-0-0" stroke-width="2px" d="M70,352.0 C70,264.5 210.0,264.5 210.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c30dffe506c447cebaa68190ac01e6ee-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,354.0 L62,342.0 78,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c30dffe506c447cebaa68190ac01e6ee-0-1" stroke-width="2px" d="M245,352.0 C245,264.5 385.0,264.5 385.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c30dffe506c447cebaa68190ac01e6ee-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,354.0 L237,342.0 253,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c30dffe506c447cebaa68190ac01e6ee-0-2" stroke-width="2px" d="M420,352.0 C420,2.0 1275.0,2.0 1275.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c30dffe506c447cebaa68190ac01e6ee-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,354.0 L412,342.0 428,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c30dffe506c447cebaa68190ac01e6ee-0-3" stroke-width="2px" d="M420,352.0 C420,264.5 560.0,264.5 560.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c30dffe506c447cebaa68190ac01e6ee-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M560.0,354.0 L568.0,342.0 552.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c30dffe506c447cebaa68190ac01e6ee-0-4" stroke-width="2px" d="M595,352.0 C595,264.5 735.0,264.5 735.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c30dffe506c447cebaa68190ac01e6ee-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M735.0,354.0 L743.0,342.0 727.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c30dffe506c447cebaa68190ac01e6ee-0-5" stroke-width="2px" d="M420,352.0 C420,177.0 915.0,177.0 915.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c30dffe506c447cebaa68190ac01e6ee-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M915.0,354.0 L923.0,342.0 907.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c30dffe506c447cebaa68190ac01e6ee-0-6" stroke-width="2px" d="M420,352.0 C420,89.5 1095.0,89.5 1095.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c30dffe506c447cebaa68190ac01e6ee-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1095.0,354.0 L1103.0,342.0 1087.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c30dffe506c447cebaa68190ac01e6ee-0-7" stroke-width="2px" d="M1295,352.0 C1295,264.5 1435.0,264.5 1435.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c30dffe506c447cebaa68190ac01e6ee-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">acomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1435.0,354.0 L1443.0,342.0 1427.0,342.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
options = {"compact": True, "distance": 80, "color": "black", "bg": "white", "font": "Arial"}
displacy.render(doc, style="dep", options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="22401c1ab0b64d998269bb5f1eb9e94e-0" class="displacy" width="770" height="297.0" direction="ltr" style="max-width: none; height: 297.0px; color: black; background: white; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Natural</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">Language</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">Processing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">Speech</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">Text</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="690">Interesting</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="690">ADJ</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-22401c1ab0b64d998269bb5f1eb9e94e-0-0" stroke-width="2px" d="M62,162.0 62,148.66666666666666 121.0,148.66666666666666 121.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-22401c1ab0b64d998269bb5f1eb9e94e-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,164.0 L58,156.0 66,156.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-22401c1ab0b64d998269bb5f1eb9e94e-0-1" stroke-width="2px" d="M142,162.0 142,148.66666666666666 201.0,148.66666666666666 201.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-22401c1ab0b64d998269bb5f1eb9e94e-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M142,164.0 L138,156.0 146,156.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-22401c1ab0b64d998269bb5f1eb9e94e-0-2" stroke-width="2px" d="M222,162.0 222,108.66666666666666 610.0,108.66666666666666 610.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-22401c1ab0b64d998269bb5f1eb9e94e-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M222,164.0 L218,156.0 226,156.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-22401c1ab0b64d998269bb5f1eb9e94e-0-3" stroke-width="2px" d="M222,162.0 222,148.66666666666666 281.0,148.66666666666666 281.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-22401c1ab0b64d998269bb5f1eb9e94e-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M281.0,164.0 L285.0,156.0 277.0,156.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-22401c1ab0b64d998269bb5f1eb9e94e-0-4" stroke-width="2px" d="M302,162.0 302,148.66666666666666 361.0,148.66666666666666 361.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-22401c1ab0b64d998269bb5f1eb9e94e-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M361.0,164.0 L365.0,156.0 357.0,156.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-22401c1ab0b64d998269bb5f1eb9e94e-0-5" stroke-width="2px" d="M222,162.0 222,135.33333333333334 444.0,135.33333333333334 444.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-22401c1ab0b64d998269bb5f1eb9e94e-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M444.0,164.0 L448.0,156.0 440.0,156.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-22401c1ab0b64d998269bb5f1eb9e94e-0-6" stroke-width="2px" d="M222,162.0 222,122.0 527.0,122.0 527.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-22401c1ab0b64d998269bb5f1eb9e94e-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M527.0,164.0 L531.0,156.0 523.0,156.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-22401c1ab0b64d998269bb5f1eb9e94e-0-7" stroke-width="2px" d="M622,162.0 622,148.66666666666666 681.0,148.66666666666666 681.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-22401c1ab0b64d998269bb5f1eb9e94e-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">acomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M681.0,164.0 L685.0,156.0 677.0,156.0" fill="currentColor"/>
# </g>
# </svg></span>
