# %% [markdown]
# [librosa](https://librosa.org/doc/latest/index.html)

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
y, sr = librosa.load('./NLP_sample_audio.wav')

# %%
y
# Out:
# array([ 7.4324618e-08, -9.2319468e-08,  1.0541592e-07, ...,
#        -1.0843783e-04, -1.2595946e-04,  0.0000000e+00], dtype=float32)

# %%
sr
# Out:
# 22050

# %%
mfccs = librosa.feature.mfcc(y=y, sr=sr)
mfccs
# Out:
# array([[-6.7242151e+02, -6.3671191e+02, -6.2943677e+02, ...,
#         -6.7498273e+02, -6.7628760e+02, -6.8481842e+02],
#        [ 3.3572098e+01,  5.8810738e+01,  6.1889717e+01, ...,
#          3.7218254e+01,  3.5287453e+01,  2.4129295e+01],
#        [ 1.9321121e+01,  1.5360357e+01,  1.2870022e+01, ...,
#          3.2494041e+01,  3.0316957e+01,  2.1546974e+01],
#        ...,
#        [-3.2605290e+00, -1.0671327e+00, -4.7576032e+00, ...,
#          7.1616020e+00,  6.8216496e+00,  1.0514230e+00],
#        [-4.4076123e+00, -1.3976448e+00, -6.4465517e-01, ...,
#          5.4438572e+00,  4.9817648e+00, -1.0210454e-02],
#        [ 2.0055850e+00,  3.0825372e+00,  3.6498780e+00, ...,
#          3.8266096e+00,  3.2432501e+00, -5.6832808e-01]], dtype=float32)

# %%
mfccs.shape
# Out:
# (20, 518)

# %%
plt.figure(figsize=(10, 4))
librosa.display.specshow(mfccs, x_axis='time')
plt.colorbar()
plt.title('MFCC for sample audio')
plt.tight_layout()
plt.show()
