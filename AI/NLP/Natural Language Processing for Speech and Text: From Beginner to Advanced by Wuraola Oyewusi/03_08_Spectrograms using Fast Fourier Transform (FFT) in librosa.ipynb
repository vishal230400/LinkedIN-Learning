# %%
import librosa
import numpy as np
import matplotlib.pyplot as plt

# %%
audio_filepath = "./NLP_sample_audio.wav"

# %%
y , sr = librosa.load(audio_filepath)

# %%
S = librosa.stft(y)
spectrogram = np.abs(S)

# %%
spectrogram
# Out:
# array([[2.77233543e-03, 3.92746106e-02, 1.61216706e-02, ...,
#         8.32890496e-02, 2.25802790e-02, 3.67509425e-02],
#        [8.04126915e-03, 4.85773981e-02, 7.16512352e-02, ...,
#         7.93628022e-02, 6.25614598e-02, 4.05844077e-02],
#        [2.85228491e-02, 6.36000559e-02, 8.88031870e-02, ...,
#         5.04322760e-02, 3.26757357e-02, 2.87292320e-02],
#        ...,
#        [6.53545911e-08, 3.60983883e-08, 3.37130523e-09, ...,
#         1.56752011e-09, 2.28465960e-05, 7.19354284e-05],
#        [6.57023023e-08, 3.58187897e-08, 7.70290998e-10, ...,
#         1.91223526e-09, 2.28405333e-05, 7.19208547e-05],
#        [6.36674855e-08, 3.81167240e-08, 1.37729255e-11, ...,
#         4.31164202e-11, 2.28390290e-05, 7.19192540e-05]], dtype=float32)

# %%
plt.figure(figsize=(12, 6))  # Adjust figure size as desired
plt.imshow(spectrogram, aspect='auto', origin='lower', cmap='inferno')  # Choose a desired colormap
plt.xlabel('Time')
plt.ylabel('Frequency')
plt.title('Spectrogram of the Audio')
plt.colorbar(format='%2.f dB')  # Display colorbar with dB scale
plt.show()

# %%
S_dB = librosa.amplitude_to_db(np.abs(S), ref=np.max)

# %%
plt.figure(figsize=(10, 5))
librosa.display.specshow(S_dB, sr=sr, x_axis='time', y_axis='log', cmap='inferno')
plt.colorbar(format='%+2.0f dB')
plt.title('STFT Spectrogram')
plt.xlabel('Time')
plt.ylabel('Frequency (Hz)')
plt.show()
