# %% [markdown]
# [Scikit Learn](https://scikit-learn.org/)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
corpus =["Natural Language Processing for Speech and Text​",
"Language Processing for Natural Speech and Text vishal​",
"Text and Speech for Natural Language Processing vishal​"]

# %%
vectorizer = TfidfVectorizer()

# %%
X = vectorizer.fit_transform(corpus)

# %%
vectorizer.get_feature_names_out()
# Out:
# array(['and', 'for', 'language', 'natural', 'processing', 'speech',
#        'text', 'vishal'], dtype=object)

# %%
X.toarray()
# Out:
# array([[0.37796447, 0.37796447, 0.37796447, 0.37796447, 0.37796447,
#         0.37796447, 0.37796447, 0.        ],
#        [0.33985062, 0.33985062, 0.33985062, 0.33985062, 0.33985062,
#         0.33985062, 0.33985062, 0.43761956],
#        [0.33985062, 0.33985062, 0.33985062, 0.33985062, 0.33985062,
#         0.33985062, 0.33985062, 0.43761956]])
